# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install kaggle
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import os

# %%
os.environ['KAGGLE_USERNAME'] = "ezmgszi"
os.environ['KAGGLE_KEY'] = "1e61368ff35db29b1a61a8fa576dc124"

# %%
# !kaggle competitions download -c hubmap-hacking-the-human-vasculature -p "/content/drive/MyDrive/Kaggle/HuBMAP - Hacking the Human Vasculature/Dataset"
# Out:
# ...
# 100% 3.97G/3.97G [02:16<00:00, 30.4MB/s]
# 100% 3.97G/3.97G [02:16<00:00, 31.1MB/s]

# %%
import zipfile

with zipfile.ZipFile('/content/drive/MyDrive/Kaggle/HuBMAP - Hacking the Human Vasculature/Dataset/hubmap-hacking-the-human-vasculature.zip', 'r') as zip_ref:
    zip_ref.extractall('/content/drive/MyDrive/Kaggle/HuBMAP - Hacking the Human Vasculature/Dataset/Data')
